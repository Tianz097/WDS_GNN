# %% [markdown]
# # Generate training data

# %% [markdown]
# 256×169 samples</p>
# ### Change demand
# timestep = 1h, 1 week ->169 timesteps in total</p>
# at every timestep, change the nodal demand</p>
# ### Change topology
# Randomly cut the connectivity between two pipes, but preserving the connectivity between each node in the network and source. ->256 topology
#
# ### Try single timestep

# %%
import wntr
import networkx as nx
import scipy.sparse as sp
import numpy as np 
import random
import tqdm
import os 
import matplotlib.pyplot as plt
import itertools
from collections import Counter 
import networkx as nx
import copy
import pandas as pd
import tensorflow_gnn as tfgnn
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# To use standard datasets that fit in memory.
from tensorflow_gnn.experimental.in_memory import datasets

# Implementations of example GNN models.
from tensorflow_gnn.experimental.in_memory import models

# Converts `tfgnn.GraphTensor` to (`tfgnn.GraphTensor`, `tf.Tensor`)
# with second item containing task labels.
from tensorflow_gnn.experimental.in_memory import reader_utils

# For on-the-fly subgraph sampling.
from tensorflow_gnn.sampler import sampling_spec_builder

# %%
def get_removable_links(inp_file):
    wn = wntr.network.WaterNetworkModel(inp_file)
    removable_links = []
    G = wn.to_graph(wn)
    # Store not-deadend pipes to be removed
    for _, link in wn.links():
        if (link.link_type == 'Pipe' and
            link.start_node.node_type == 'Junction' and
            link.end_node.node_type == 'Junction' and
            G.degree[link.start_node.name] > 1 and
            G.degree[link.end_node.name] > 1):
            removable_links.append(link)
    # To find pairs of links that can be removed together while keeping the network graph connected
    removable_pairs = []
    for (link1, link2) in itertools.combinations(removable_links, 2):
        wnr = copy.deepcopy(wn)  #create a new reference to the same object
        wnr.remove_link(link1)
        wnr.remove_link(link2)
        Gr = wnr.to_graph().to_undirected()
        if nx.is_connected(Gr):
            removable_pairs.append((link1, link2))

    return removable_links, removable_pairs

# %%
network = 'ASnet2'
inp_file = network + '.inp'
wn = wntr.network.WaterNetworkModel(inp_file)

# get removable links
removable_links, removable_pairs = get_removable_links(inp_file)
num_nodes = wn.num_nodes
num_links = wn.num_links
#num_time = 169
num_time = int(wn.options.time.duration / wn.options.time.report_timestep + 1)

# %%
start_value = 0
end_value = 604800
interval = 3600
Time_step = np.arange(start_value, end_value + 1, interval)
print(Time_step.size)
# Out:
# 169

# %%
n_sims = 128
#𝑉_𝑖=[ 𝐼_𝑖^𝑑, 𝑞_𝑖, 𝐼_𝑖^𝑚,𝐻_𝑖^∗ ] 
#𝐸_𝑝=[𝑖,𝑗,𝑐_𝑝]
#Create data matrix
A = np.zeros((n_sims , num_links*num_time, 4))
B = np.zeros((n_sims , num_nodes*num_time, 6))
U = np.zeros((n_sims , num_nodes*num_time, 1))



# Store the randomly chosen pairs of removable links
links2remove = random.sample(removable_pairs, n_sims)

## Measurement when fully-supervised
measurement_fully = []
monitor = ['5', '11', '32', '37', '44']

# %%
for sim in range(n_sims):
    wn = wntr.network.WaterNetworkModel(inp_file)  # reset value
    wn.options.hydraulic.demand_model = 'DD' #dynamic demand model

    i = 0
    for _, node in wn.nodes():
        node.id = i
        i += 1

    if sim != 0:
        (link1, link2) = links2remove[sim - 1]
        wn.remove_link(link1)
        wn.remove_link(link2)

    #i = 0
    #for _, link in wn.links():
     #   A[sim, i, 0] = link.start_node.id
      #  A[sim, i, 1] = link.end_node.id
       # A[sim, i, 2] = 1 / (10.667 *link.length / link.roughness ** 1.852 /link.diameter ** 4.871)
        #i += 1

    results = wntr.sim.EpanetSimulator(wn).run_sim(version=2.0)
    head = results.node['head']
    demand = results.node['demand']
    flow = results.link['flowrate']
    headloss = results.link['headloss']
    demand = np.maximum(demand, 0)
    
    ### Produce datas for multiple timestep
    #### Time step
    index_values = head.index.values
    #np.random.seed(42)
    #Time_step = np.random.choice(index_values, size=num_time, replace=False)
    
    repeated_timestep = pd.Series(Time_step).repeat(num_nodes).reset_index(drop=True)
    Time_indicator = pd.DataFrame({'Timestep': repeated_timestep})
    Time_indicator = Time_indicator.squeeze()
    
    #### Demand
    demand_s = demand.loc[Time_step]
    demand_s = demand_s.values.flatten()
    #### Head
    head_s = head.loc[Time_step]
    head_s = head_s.values.flatten()
    #### Flow
    flow_s = flow.loc[Time_step]
    flow_s = flow_s.values.flatten()
    #### Headloss
    hl_s = headloss.loc[Time_step]
    hl_s = hl_s.values.flatten()
    
    #### Node indicator (the number of the node)
    Node_indicator = np.tile(np.arange(1, num_nodes+1), num_time)
        # Measurement when fully-supervised
    measurement_fully = Node_indicator
    #### Junction indicator (if the node is not a reservoir, junction indicator = 1)
    Nd_single = np.array([1 if node.node_type == 'Junction' else 0 for _, node in wn.nodes()])
    Nd = np.tile(Nd_single,num_time)
    Nd = Nd.squeeze()
    #### Measurement indicator (if the node has head, measurement indicator = 1) (fully-supervised, all 1)
    Nh_single = np.zeros(num_nodes)
    Nh = np.tile(Nh_single,num_time)
    Nh = Nh.squeeze()
    ###
    A[sim, :, 2] = hl_s
    A[sim, :, 3] = flow_s
    
    ### Node
    B[sim, :, 0] = Time_indicator
    B[sim, :, 1] = Node_indicator
    B[sim, :, 2] = Nd
    B[sim, :, 3] = demand_s
    B[sim, :, 4] = Nh
    B[sim, :, 5] = (1 - Nh) * head_s
    ###

    U[sim, :, 0] = head_s

# %%
### Edge
A_re = A[:, :num_links, :]  # Extract the first 65 rows along the second axis

# Repeat the 65 rows to cover the entire second axis
A_re = np.tile(A_re, (1, num_time, 1))

# %% [markdown]
# ### Change 3-d array to DataFrame

# %%
array_3d_shape = B.shape
new_shape = (array_3d_shape[0]* array_3d_shape[1] ,array_3d_shape[2])

# Reshaping the 3-dimensional array into a 2-dimensional array
B_2d = B.reshape(new_shape)

# Converting the 2-dimensional array into a DataFrame
node_df = pd.DataFrame(B_2d)

array_3d_shape = A_re.shape
new_shape = (array_3d_shape[0]* array_3d_shape[1] ,array_3d_shape[2])

# Reshaping the 3-dimensional array into a 2-dimensional array
A_2d = A_re.reshape(new_shape)

# Converting the 2-dimensional array into a DataFrame
edge_df = pd.DataFrame(A_2d)

array_3d_shape = U.shape
new_shape = (array_3d_shape[0]* array_3d_shape[1] ,array_3d_shape[2])

# Reshaping the 3-dimensional array into a 2-dimensional array
U_2d = U.reshape(new_shape)

# Converting the 2-dimensional array into a DataFrame
graph_df = pd.DataFrame(U_2d)

# %%
graph_df.rename(columns={0: 'head'},inplace=True)
edge_df.rename(columns={0: 'source', 1: 'target', 2: 'loss_co',3:'flowrate'},inplace=True)
node_df.rename(columns={0:'Time_indicator', 1: 'Node_indicator', 2:'Junction_in',3: 'demand', 4: 'Measurement_in',5:'measurement'},inplace=True)

# %% [markdown]
# ## Scale the data

# %%
# Edge
# Column names to scale
column_to_scale = ['loss_co', 'flowrate']

# Create a StandardScaler object
scaler = StandardScaler()

# Fit and transform the selected columns
edge_df[column_to_scale] = scaler.fit_transform(edge_df[column_to_scale])

# Node
## Create a StandardScaler object
scaler = StandardScaler()

## Select the column to scale
columns_to_scale = ['demand', 'measurement']

# Fit and transform the selected columns
node_df[columns_to_scale] = scaler.fit_transform(node_df[columns_to_scale])
#

edge_df.head(51)
# Out:
#     source  target   loss_co  flowrate
# 0      0.0     0.0 -0.249191  0.321888
# 1      0.0     0.0 -0.249454  0.179553
# 2      0.0     0.0 -0.235748  0.037666
# 3      0.0     0.0 -0.241913  0.086816
# 4      0.0     0.0 -0.245088  0.119555
# 5      0.0     0.0 -0.137295 -0.369479
# 6      0.0     0.0 -0.248247  0.161027
# 7      0.0     0.0 -0.176120 -0.245364
# 8      0.0     0.0 -0.099951 -0.471406
# 9      0.0     0.0 -0.121074 -0.415421
# 10     0.0     0.0 -0.144255 -0.348206
# 11     0.0     0.0 -0.240470  0.074546
# 12     0.0     0.0 -0.224165 -0.036389
# 13     0.0     0.0 -0.240001  0.070530
# 14     0.0     0.0 -0.225587 -0.027685
# 15     0.0     0.0 -0.209231 -0.112655
# 16     0.0     0.0 -0.245648  0.125236
# 17     0.0     0.0 -0.251377  0.248606
# 18     0.0     0.0 -0.193748 -0.178941
# 19     0.0     0.0 -0.227176 -0.018956
# 20     0.0     0.0 -0.069967 -0.545070
# 21     0.0     0.0 -0.151589 -0.326382
# 22     0.0     0.0 -0.158123 -0.305671
# 23     0.0     0.0 -0.122785 -0.410660
# 24     0.0     0.0 -0.082955 -0.514022
# 25     0.0     0.0 -0.003050 -0.691896
# 26     0.0     0.0  0.058330 -0.810959
# 27     0.0     0.0  1.898355 -2.767779
# 28     0.0     0.0  1.850329  3.228358
# 29     0.0     0.0 -0.083045 -0.513825
# 30     0.0     0.0 -0.225590 -0.028347
# 31     0.0     0.0 -0.179329 -0.233689
# 32     0.0     0.0  0.017471 -0.732999
# 33     0.0     0.0 -0.205755  0.625994
# 34     0.0     0.0 -0.178006  0.735237
# 35     0.0     0.0  0.125301 -0.929532
# 36     0.0     0.0 -0.120822  0.913187
# 37     0.0     0.0 -0.211583  0.598486
# 38     0.0     0.0 -0.207082  0.619831
# 39     0.0     0.0 -0.221235  0.549295
# 40     0.0     0.0 -0.173666  0.750133
# 41     0.0     0.0 -0.188172  0.697928
# 42     0.0     0.0 -0.251377  0.260115
# 43     0.0     0.0 -0.230447  0.495809
# 44     0.0     0.0 -0.238055  0.442453
# 45     0.0     0.0 -0.240871  0.419372
# 46     0.0     0.0 -0.219155  0.560621
# 47     0.0     0.0 -0.212441  0.594370
# 48     0.0     0.0 -0.234147  0.471452
# 49     0.0     0.0 -0.244962  0.379401
# 50     0.0     0.0 -0.231859  0.487438

# %%
test_edge_df = edge_df[n_sims * num_links * (num_time - 34):]
test_node_df = node_df[n_sims * num_nodes * (num_time - 34):]

train_edge_df = edge_df[:n_sims * num_links * (num_time - 100)]
train_node_df = node_df[:n_sims * num_nodes * (num_time - 100)]

vali_edge_df = edge_df[n_sims * num_links * (num_time - 67):n_sims * num_links * (num_time - 34)]
vali_node_df = node_df[n_sims * num_nodes * (num_time - 67):n_sims * num_nodes * (num_time - 34)]

# %%
def create_graph_tensor(node_df, edge_df):
    graph_tensor = tfgnn.GraphTensor.from_pieces(

        node_sets={
            "node": tfgnn.NodeSet.from_fields(
                sizes=[len(node_df)],
                features={
                    #'Node_indicator':np.array(node_df['Node_indicator'], dtype='int32').reshape(len(node_df),1),
                    'Junction_in':np.array(node_df['Junction_in'], dtype='int32').reshape(len(node_df),1),
                    'demand': np.array(node_df['demand'], dtype='float32').reshape(len(node_df),1),
                    'Measurement_in': np.array(node_df['Measurement_in'], dtype='int32').reshape(len(node_df),1),
                    'measurement': np.array(node_df['measurement'], dtype='float32').reshape(len(node_df),1),
                }
            )
        },
        edge_sets={
            "link": tfgnn.EdgeSet.from_fields(
                sizes=[len(edge_df)],
                features={
                    'loss_co': np.array(edge_df['loss_co'], dtype='float32').reshape(len(edge_df),1),
                   # 'flowrate': np.array(edge_df['flowrate'], dtype='float32').reshape(len(edge_df),1),
                },
                adjacency=tfgnn.Adjacency.from_indices(
                                          source=("node", np.array(edge_df['source'], dtype='int32')),
                                          target=("node", np.array(edge_df['target'], dtype='int32')),
                                      ))
        }
    )

    return graph_tensor

# %%
full_tensor = create_graph_tensor(node_df, edge_df)
train_tensor = create_graph_tensor(train_node_df, train_edge_df)
test_tensor = create_graph_tensor(test_node_df, test_edge_df)
vali_tensor = create_graph_tensor(vali_node_df, vali_edge_df)

# %% [markdown]
# split off ‘head’ as our target (label).

# %%
def node_batch_merge(graph):
    graph = graph.merge_batch_to_components()
    node_features = graph.node_sets['node'].get_features_dict()
    edge_features = graph.edge_sets['link'].get_features_dict()
    
    label = node_features.pop('measurement')
    print(label)
    new_graph = graph.replace_features(node_sets={'node': node_features}, edge_sets={'link': edge_features})
    
    return new_graph, label


     
def create_dataset(graph, function):
    dataset = tf.data.Dataset.from_tensors(graph)
    dataset = dataset.batch(32)
    return dataset.map(function)

# %% [markdown]
# ### Train dataset

# %%
full_node_dataset = create_dataset(full_tensor, node_batch_merge)
train_node_dataset = create_dataset(train_tensor, node_batch_merge)
test_node_dataset = create_dataset(test_tensor, node_batch_merge)
vali_node_dataset = create_dataset(vali_tensor, node_batch_merge)
# Out:
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)

# %%
for graph,label in full_node_dataset:
    break
    
print(graph)
print(label)
# Out:
# GraphTensor(
#   context=Context(features={}, sizes=[1], shape=(), indices_dtype=tf.int32),
#   node_set_names=['node'],
#   edge_set_names=['link'])
# tf.Tensor(
# [[0.237]
#  [0.236]
#  [0.237]
#  ...
#  [0.241]
#  [0.241]
#  [2.346]], shape=(1103232, 1), dtype=float32)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Build model inputs

# %%
graph_spec = train_node_dataset.element_spec[0]
input_graph = tf.keras.layers.Input(type_spec=graph_spec)

# %%
def set_initial_node_state(node_set, node_set_name):
    features = [
        #tf.keras.layers.Dense(32, activation="relu")(node_set['Node_indicator']),
        tf.keras.layers.Dense(32, activation=tf.nn.leaky_relu)(node_set['Junction_in']),
        tf.keras.layers.Dense(32, activation=tf.nn.leaky_relu)(node_set['demand']),
        tf.keras.layers.Dense(32, activation=tf.nn.leaky_relu)(node_set['Measurement_in']),
        #tf.keras.layers.Dense(32, activation="relu")(node_set['measurement']),
    ]
    return tf.keras.layers.Concatenate()(features)


def set_initial_edge_state(edge_set, edge_set_name):
    features = [
        tf.keras.layers.Dense(32, activation="leaky_relu")(edge_set['loss_co']),
        #tf.keras.layers.Dense(32, activation="leaky_relu")(edge_set['flowrate']),
    ]
    return tf.keras.layers.Concatenate()(features)

# %%
graph = tfgnn.keras.layers.MapFeatures(node_sets_fn=set_initial_node_state,
                                       edge_sets_fn=set_initial_edge_state)(input_graph)
# Out:
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>

# %%
def dense_layer(units=32, l2_reg=5e-4, dropout=0.5, activation='tf.nn.leaky_relu'):
    regularizer = tf.keras.regularizers.l2(l2_reg)
    return tf.keras.Sequential([
        tf.keras.layers.Dense(units, kernel_initializer='glorot_normal',kernel_regularizer=regularizer, bias_regularizer=regularizer),
        tf.keras.layers.Dropout(dropout)
    ])

# %% [markdown]
# ### Compile

# %%
graph_updates = 3
l2_reg = 5e-4
regularizer = tf.keras.regularizers.l2(l2_reg)
for i in range(graph_updates):
    graph = tfgnn.keras.layers.GraphUpdate(
        node_sets={
            'node':
            tfgnn.keras.layers.NodeSetUpdate(
                {
                    'link':
                    tfgnn.keras.layers.SimpleConv(message_fn=dense_layer(64),
                                                  reduce_type="mean",
                                                  sender_edge_feature=tfgnn.HIDDEN_STATE,
                                                  receiver_tag=tfgnn.TARGET)
                }, tfgnn.keras.layers.NextStateFromConcat(dense_layer(64)))
        })(graph)
    dense1 = tf.keras.layers.Dense(1,activation=tf.nn.leaky_relu)(graph.node_sets["node"][tfgnn.HIDDEN_STATE])
    #dense2 = tf.keras.layers.Dense(64)(dense1)
    #dense3 = tf.keras.layers.Dense(1)(dense2)

# %%
node_model = tf.keras.Model(input_graph, dense1)
node_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                   loss='mean_squared_error',
                   metrics=['mean_squared_error'])
node_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [()]                      0
#
#  map_features (MapFeatures)  ()                        256
#
#  graph_update (GraphUpdate)  ()                        24704
#
#  graph_update_1 (GraphUpdate  ()                       18560
#  )
#
#  graph_update_2 (GraphUpdate  ()                       18560
#  )
#
#  graph_update_3 (GraphUpdate  ()                       18560
#  )
#
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
#  input.node_sets_3 (Instance  {'node': ()}             0
#  Property)
#
#  input._get_features_ref_7 (  {'hidden_state': (None,   0
#  InstanceProperty)           64)}
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 80,705
# Trainable params: 80,705
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train model

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                      mode='min',
                                      verbose=1,
                                      patience=3,
                                      restore_best_weights=True)

node_model.fit(train_node_dataset.repeat(),
               validation_data=vali_node_dataset,
               steps_per_epoch=10,
               epochs=100,
               callbacks=[es])
# Out:
# Epoch 1/100
# 10/10 [==============================] - 48s 5s/step - loss: 1.2928 - mean_squared_error: 0.9529 - val_loss: 1.1627 - val_mean_squared_error: 0.8478
# Epoch 2/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.1722 - mean_squared_error: 0.8761 - val_loss: 1.1077 - val_mean_squared_error: 0.8338
# Epoch 3/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.1076 - mean_squared_error: 0.8503 - val_loss: 1.0489 - val_mean_squared_error: 0.8108
# Epoch 4/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0532 - mean_squared_error: 0.8292 - val_loss: 0.9988 - val_mean_squared_error: 0.7907
# Epoch 5/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0076 - mean_squared_error: 0.8114 - val_loss: 0.9610 - val_mean_squared_error: 0.7786
# Epoch 6/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9721 - mean_squared_error: 0.7996 - val_loss: 0.9285 - val_mean_squared_error: 0.7676
# Epoch 7/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.9414 - mean_squared_error: 0.7890 - val_loss: 0.9023 - val_mean_squared_error: 0.7598
# Epoch 8/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.9134 - mean_squared_error: 0.7782 - val_loss: 0.8776 - val_mean_squared_error: 0.7506
# Epoch 9/100
# 10/10 [==============================] - 55s 5s/step - loss: 0.8879 - mean_squared_error: 0.7670 - val_loss: 0.8537 - val_mean_squared_error: 0.7398
# Epoch 10/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.8645 - mean_squared_error: 0.7556 - val_loss: 0.8316 - val_mean_squared_error: 0.7285
# Epoch 11/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.8449 - mean_squared_error: 0.7460 - val_loss: 0.8154 - val_mean_squared_error: 0.7213
# Epoch 12/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.8311 - mean_squared_error: 0.7407 - val_loss: 0.8036 - val_mean_squared_error: 0.7177
# Epoch 13/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.8201 - mean_squared_error: 0.7375 - val_loss: 0.7943 - val_mean_squared_error: 0.7157
# Epoch 14/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.8110 - mean_squared_error: 0.7353 - val_loss: 0.7870 - val_mean_squared_error: 0.7148
# Epoch 15/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.8033 - mean_squared_error: 0.7337 - val_loss: 0.7810 - val_mean_squared_error: 0.7143
# Epoch 16/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.7969 - mean_squared_error: 0.7324 - val_loss: 0.7752 - val_mean_squared_error: 0.7133
# Epoch 17/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7914 - mean_squared_error: 0.7315 - val_loss: 0.7707 - val_mean_squared_error: 0.7131
# Epoch 18/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.7864 - mean_squared_error: 0.7306 - val_loss: 0.7663 - val_mean_squared_error: 0.7125
# Epoch 19/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7818 - mean_squared_error: 0.7296 - val_loss: 0.7624 - val_mean_squared_error: 0.7120
# Epoch 20/100
# 10/10 [==============================] - 57s 6s/step - loss: 0.7778 - mean_squared_error: 0.7288 - val_loss: 0.7588 - val_mean_squared_error: 0.7114
# Epoch 21/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7742 - mean_squared_error: 0.7279 - val_loss: 0.7562 - val_mean_squared_error: 0.7113
# Epoch 22/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7715 - mean_squared_error: 0.7278 - val_loss: 0.7529 - val_mean_squared_error: 0.7104
# Epoch 23/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7682 - mean_squared_error: 0.7267 - val_loss: 0.7503 - val_mean_squared_error: 0.7099
# Epoch 24/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7654 - mean_squared_error: 0.7258 - val_loss: 0.7479 - val_mean_squared_error: 0.7093
# Epoch 25/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7630 - mean_squared_error: 0.7251 - val_loss: 0.7457 - val_mean_squared_error: 0.7088
# Epoch 26/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7610 - mean_squared_error: 0.7248 - val_loss: 0.7439 - val_mean_squared_error: 0.7085
# Epoch 27/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7587 - mean_squared_error: 0.7240 - val_loss: 0.7420 - val_mean_squared_error: 0.7080
# Epoch 28/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7577 - mean_squared_error: 0.7243 - val_loss: 0.7410 - val_mean_squared_error: 0.7084
# Epoch 29/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7553 - mean_squared_error: 0.7232 - val_loss: 0.7387 - val_mean_squared_error: 0.7073
# Epoch 30/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7536 - mean_squared_error: 0.7226 - val_loss: 0.7379 - val_mean_squared_error: 0.7075
# Epoch 31/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7522 - mean_squared_error: 0.7222 - val_loss: 0.7363 - val_mean_squared_error: 0.7069
# Epoch 32/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7512 - mean_squared_error: 0.7222 - val_loss: 0.7355 - val_mean_squared_error: 0.7071
# Epoch 33/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7500 - mean_squared_error: 0.7220 - val_loss: 0.7340 - val_mean_squared_error: 0.7065
# Epoch 34/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7488 - mean_squared_error: 0.7217 - val_loss: 0.7338 - val_mean_squared_error: 0.7071
# Epoch 35/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7477 - mean_squared_error: 0.7214 - val_loss: 0.7320 - val_mean_squared_error: 0.7061
# Epoch 36/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7465 - mean_squared_error: 0.7210 - val_loss: 0.7314 - val_mean_squared_error: 0.7063
# Epoch 37/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7457 - mean_squared_error: 0.7209 - val_loss: 0.7308 - val_mean_squared_error: 0.7063
# Epoch 38/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7449 - mean_squared_error: 0.7207 - val_loss: 0.7297 - val_mean_squared_error: 0.7059
# Epoch 39/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7443 - mean_squared_error: 0.7208 - val_loss: 0.7292 - val_mean_squared_error: 0.7060
# Epoch 40/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7433 - mean_squared_error: 0.7204 - val_loss: 0.7284 - val_mean_squared_error: 0.7058
# Epoch 41/100
# 10/10 [==============================] - 61s 6s/step - loss: 0.7425 - mean_squared_error: 0.7202 - val_loss: 0.7280 - val_mean_squared_error: 0.7060
# Epoch 42/100
# 10/10 [==============================] - 68s 7s/step - loss: 0.7418 - mean_squared_error: 0.7201 - val_loss: 0.7269 - val_mean_squared_error: 0.7055
# Epoch 43/100
# 10/10 [==============================] - 64s 6s/step - loss: 0.7413 - mean_squared_error: 0.7201 - val_loss: 0.7262 - val_mean_squared_error: 0.7053
# Epoch 44/100
# 10/10 [==============================] - 63s 6s/step - loss: 0.7409 - mean_squared_error: 0.7202 - val_loss: 0.7273 - val_mean_squared_error: 0.7069
# Epoch 45/100
# 10/10 [==============================] - 92s 9s/step - loss: 0.7402 - mean_squared_error: 0.7200 - val_loss: 0.7253 - val_mean_squared_error: 0.7053
# Epoch 46/100
# 10/10 [==============================] - 43s 4s/step - loss: 0.7394 - mean_squared_error: 0.7197 - val_loss: 0.7247 - val_mean_squared_error: 0.7052
# Epoch 47/100
# 10/10 [==============================] - 44s 4s/step - loss: 0.7388 - mean_squared_error: 0.7195 - val_loss: 0.7242 - val_mean_squared_error: 0.7051
# Epoch 48/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7385 - mean_squared_error: 0.7196 - val_loss: 0.7241 - val_mean_squared_error: 0.7055
# Epoch 49/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7382 - mean_squared_error: 0.7197 - val_loss: 0.7236 - val_mean_squared_error: 0.7053
# Epoch 50/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7375 - mean_squared_error: 0.7194 - val_loss: 0.7229 - val_mean_squared_error: 0.7050
# Epoch 51/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.7373 - mean_squared_error: 0.7196 - val_loss: 0.7230 - val_mean_squared_error: 0.7054
# Epoch 52/100
# 10/10 [==============================] - 90s 9s/step - loss: 0.7368 - mean_squared_error: 0.7194 - val_loss: 0.7227 - val_mean_squared_error: 0.7055
# Epoch 53/100
# 10/10 [==============================] - 44s 4s/step - loss: 0.7363 - mean_squared_error: 0.7193 - val_loss: 0.7222 - val_mean_squared_error: 0.7053
# Epoch 54/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.7359 - mean_squared_error: 0.7191 - val_loss: 0.7216 - val_mean_squared_error: 0.7050
# Epoch 55/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.7355 - mean_squared_error: 0.7190 - val_loss: 0.7214 - val_mean_squared_error: 0.7051
# Epoch 56/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7357 - mean_squared_error: 0.7195 - val_loss: 0.7212 - val_mean_squared_error: 0.7052
# Epoch 57/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7349 - mean_squared_error: 0.7190 - val_loss: 0.7207 - val_mean_squared_error: 0.7049
# Epoch 58/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.7345 - mean_squared_error: 0.7189 - val_loss: 0.7205 - val_mean_squared_error: 0.7050
# Epoch 59/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.7346 - mean_squared_error: 0.7193 - val_loss: 0.7204 - val_mean_squared_error: 0.7051
# Epoch 60/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.7343 - mean_squared_error: 0.7191 - val_loss: 0.7207 - val_mean_squared_error: 0.7057
# Epoch 61/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7338 - mean_squared_error: 0.7189 - val_loss: 0.7197 - val_mean_squared_error: 0.7049
# Epoch 62/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7334 - mean_squared_error: 0.7187 - val_loss: 0.7194 - val_mean_squared_error: 0.7049
# Epoch 63/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7333 - mean_squared_error: 0.7188 - val_loss: 0.7192 - val_mean_squared_error: 0.7048
# Epoch 64/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.7329 - mean_squared_error: 0.7187 - val_loss: 0.7192 - val_mean_squared_error: 0.7050
# Epoch 65/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.7329 - mean_squared_error: 0.7188 - val_loss: 0.7188 - val_mean_squared_error: 0.7048
# Epoch 66/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.7324 - mean_squared_error: 0.7185 - val_loss: 0.7186 - val_mean_squared_error: 0.7048
# Epoch 67/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7333 - mean_squared_error: 0.7196 - val_loss: 0.7189 - val_mean_squared_error: 0.7054
# Epoch 68/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7324 - mean_squared_error: 0.7189 - val_loss: 0.7183 - val_mean_squared_error: 0.7049
# Epoch 69/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7318 - mean_squared_error: 0.7185 - val_loss: 0.7179 - val_mean_squared_error: 0.7047
# Epoch 70/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7318 - mean_squared_error: 0.7186 - val_loss: 0.7180 - val_mean_squared_error: 0.7049
# Epoch 71/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7314 - mean_squared_error: 0.7184 - val_loss: 0.7178 - val_mean_squared_error: 0.7049
# Epoch 72/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7313 - mean_squared_error: 0.7185 - val_loss: 0.7174 - val_mean_squared_error: 0.7047
# Epoch 73/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7314 - mean_squared_error: 0.7187 - val_loss: 0.7178 - val_mean_squared_error: 0.7052
# Epoch 74/100
# 10/10 [==============================] - 64s 6s/step - loss: 0.7316 - mean_squared_error: 0.7191 - val_loss: 0.7176 - val_mean_squared_error: 0.7051
# Epoch 75/100
# 10/10 [==============================] - 66s 7s/step - loss: 0.7313 - mean_squared_error: 0.7189 - val_loss: 0.7174 - val_mean_squared_error: 0.7051
# Epoch 76/100
# 10/10 [==============================] - 63s 6s/step - loss: 0.7308 - mean_squared_error: 0.7185 - val_loss: 0.7170 - val_mean_squared_error: 0.7048
# Epoch 77/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.7305 - mean_squared_error: 0.7183 - val_loss: 0.7168 - val_mean_squared_error: 0.7047
# Epoch 78/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.7304 - mean_squared_error: 0.7184 - val_loss: 0.7168 - val_mean_squared_error: 0.7048
# Epoch 79/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7306 - mean_squared_error: 0.7187 - val_loss: 0.7167 - val_mean_squared_error: 0.7048
# Epoch 80/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7303 - mean_squared_error: 0.7185 - val_loss: 0.7169 - val_mean_squared_error: 0.7052
# Epoch 81/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7300 - mean_squared_error: 0.7184 - val_loss: 0.7164 - val_mean_squared_error: 0.7048
# Epoch 82/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.7298 - mean_squared_error: 0.7183 - val_loss: 0.7163 - val_mean_squared_error: 0.7047
# Epoch 83/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.7305 - mean_squared_error: 0.7190 - val_loss: 0.7162 - val_mean_squared_error: 0.7048
# Epoch 84/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7298 - mean_squared_error: 0.7185 - val_loss: 0.7163 - val_mean_squared_error: 0.7050
# Epoch 85/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.7296 - mean_squared_error: 0.7184 - val_loss: 0.7159 - val_mean_squared_error: 0.7047
# Epoch 86/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7296 - mean_squared_error: 0.7184 - val_loss: 0.7160 - val_mean_squared_error: 0.7049
# Epoch 87/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7295 - mean_squared_error: 0.7184 - val_loss: 0.7158 - val_mean_squared_error: 0.7047
# Epoch 88/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7292 - mean_squared_error: 0.7182 - val_loss: 0.7157 - val_mean_squared_error: 0.7048
# Epoch 89/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.7297 - mean_squared_error: 0.7188 - val_loss: 0.7157 - val_mean_squared_error: 0.7049
# Epoch 90/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7292 - mean_squared_error: 0.7184 - val_loss: 0.7157 - val_mean_squared_error: 0.7050
# Epoch 91/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.7290 - mean_squared_error: 0.7183 - val_loss: 0.7155 - val_mean_squared_error: 0.7048
# Epoch 92/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.7288 - mean_squared_error: 0.7182 - val_loss: 0.7155 - val_mean_squared_error: 0.7049
# Epoch 93/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7287 - mean_squared_error: 0.7181 - val_loss: 0.7153 - val_mean_squared_error: 0.7048
# Epoch 94/100
# 10/10 [==============================] - 50s 5s/step - loss: 0.7292 - mean_squared_error: 0.7187 - val_loss: 0.7153 - val_mean_squared_error: 0.7049
# Epoch 95/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.7287 - mean_squared_error: 0.7183 - val_loss: 0.7151 - val_mean_squared_error: 0.7047
# Epoch 96/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7283 - mean_squared_error: 0.7180 - val_loss: 0.7150 - val_mean_squared_error: 0.7047
# Epoch 97/100
# 10/10 [==============================] - 54s 5s/step - loss: 0.7286 - mean_squared_error: 0.7184 - val_loss: 0.7157 - val_mean_squared_error: 0.7055
# Epoch 98/100
# 10/10 [==============================] - 51s 5s/step - loss: 0.7285 - mean_squared_error: 0.7183 - val_loss: 0.7148 - val_mean_squared_error: 0.7047
# Epoch 99/100
# 10/10 [==============================] - 53s 5s/step - loss: 0.7283 - mean_squared_error: 0.7182 - val_loss: 0.7147 - val_mean_squared_error: 0.7046
# Epoch 100/100
# 10/10 [==============================] - 52s 5s/step - loss: 0.7283 - mean_squared_error: 0.7182 - val_loss: 0.7148 - val_mean_squared_error: 0.7047

# %%
#node_model.fit(train_node_dataset.repeat(),
 #              validation_data=full_node_dataset,
  #             steps_per_epoch=100,
   #            epochs=60,
    #           callbacks=[es])

# %% [markdown]
# ### Evaluate model

# %%
eval_result = node_model.evaluate(test_node_dataset)
print(dict(zip(node_model.metrics_names, eval_result)))
# Out:
# 1/1 [==============================] - 1s 664ms/step - loss: 0.7148 - mean_squared_error: 0.7048
# {'loss': 0.7148160934448242, 'mean_squared_error': 0.7047913074493408}

# %%
predictions = pd.DataFrame(node_model.predict(full_node_dataset))
print(predictions)
# Out:
# 1/1 [==============================] - 3s 3s/step
#                 0
# 0        0.282788
# 1       -0.393775
# 2       -0.378965
# 3       -0.817466
# 4       -0.022912
# ...           ...
# 1103227  0.635043
# 1103228  0.043247
# 1103229  0.043247
# 1103230  0.043247
# 1103231  2.211444
#
# [1103232 rows x 1 columns]

# %%
correlation = node_df['measurement'].corr(predictions[0])
residuals =  node_df['measurement']- (predictions[0])
print(correlation)
print(residuals)
# Out:
# 0.5446049995384228
# 0         -0.045695
# 1          0.629725
# 2          0.615677
# 3          1.065794
# 4          0.262670
#              ...
# 1103227    0.055553
# 1103228    0.427517
# 1103229    0.197972
# 1103230    0.197972
# 1103231    0.135035
# Length: 1103232, dtype: float64

# %%
eval_result = node_model.evaluate(test_node_dataset)
print(dict(zip(node_model.metrics_names, eval_result)))
# Out:
# 1/1 [==============================] - 1s 592ms/step - loss: 0.7148 - mean_squared_error: 0.7048
# {'loss': 0.7148160934448242, 'mean_squared_error': 0.7047913074493408}

# %%
predictions = pd.DataFrame(node_model.predict(full_node_dataset))
correlation = node_df['measurement'].corr(predictions[0])
print(correlation)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 0.5446049995384228
