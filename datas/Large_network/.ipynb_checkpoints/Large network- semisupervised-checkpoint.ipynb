# %%
## Import

# %%
import wntr
import networkx as nx
import scipy.sparse as sp
import numpy as np 
import random
import tqdm
import os 
import matplotlib.pyplot as plt
import itertools
from collections import Counter 
import networkx as nx
import copy
import pandas as pd
import tensorflow_gnn as tfgnn
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
## Import network

# %%
network = 'stkl_no_control'
inp_file = network + '.inp'
wn = wntr.network.WaterNetworkModel(inp_file)

# %%
wn = wntr.network.WaterNetworkModel(inp_file)  # reset value
wn.options.hydraulic.demand_model = 'DD' #dynamic demand model
results = wntr.sim.EpanetSimulator(wn).run_sim(version=2.0)
head = results.node['head']
demand = results.node['demand']
demand = np.maximum(demand, 0)

# %%
timesteps = demand.index.tolist()

# %%
monitor_point = pd.read_excel('Monitor_points.xlsx')
monitor = monitor_point['Branch point'].sample(n= 110, random_state=42)

# %%
# Calculate the total number of timesteps
num_timesteps = len(timesteps)

# Initialize the 3-dimensional array 'A' to store link information
num_links = wn.num_links
A = np.zeros((num_timesteps, num_links, 4))
loss_co = results.link['friction_factor']
# Outer loop to go through each timestep in the sequence
for timestep_idx in range(num_timesteps):
    # Inner loop to go through each link in the water network
    for i, (_, link) in enumerate(wn.links()):
        # Extract the numeric part of the node names using string manipulation
        start_node_name = link.start_node.name
        end_node_name = link.end_node.name
        A[timestep_idx, i, 0] =float( start_node_name[-4:])
        A[timestep_idx, i, 1] = float(end_node_name[-4:])
        A[timestep_idx, i, 2] = float(link.name[-4:])
        # Access loss coefficient from the DataFrame 'loss_co'
        if link.link_type=='Pipe':
            A[timestep_idx, i, 3] = 1/(10.667*link.length/link.roughness**1.852/link.diameter**4.871)
            i+=1
        elif link.link_type=='Pump':
            A[timestep_idx, i, 3] = 1        
        elif link.link_type=='Valve':
            A[timestep_idx, i, 3] = 2        
        else:
            print('Other types of links exist.')

# After the loops, 'A' will contain the required link information for each timestep

# %%
num_nodes = wn.num_nodes
B = np.zeros((num_timesteps, num_nodes, 6))

Node_indicator = np.tile(np.arange(1, num_nodes+1), num_timesteps)
Nd_single = np.array([0 if node.node_type=='Junction' and node.name not in monitor
                   else 1 for _,node in wn.nodes()])
Nd = np.tile(Nd_single,num_timesteps)
Nd = Nd.squeeze()
#### Measurement indicator (if the node has head, measurement indicator = 1) (fully-supervised, all 1)
Nh_single = np.zeros(num_nodes)
Nh = np.tile(Nh_single,num_timesteps)
Nh = Nh.squeeze()

for timestep_idx in range(num_timesteps):

    for i, (_, node) in enumerate(wn.nodes()):
        B[timestep_idx, i, 0] = timesteps[timestep_idx]
        B[timestep_idx, i, 1] = float(node.name[-4:])
        B[timestep_idx, i, 2] = Nd[i]
        B[timestep_idx, i, 3] = demand.iloc[timestep_idx][i]*3.6
        B[timestep_idx, i, 4] = Nh[i]
        B[timestep_idx, i, 5] = head.iloc[timestep_idx][i]

# %%
U = np.zeros((num_timesteps, num_nodes, 2))
timestep_idx = 0
for timestep_idx in range(num_timesteps):
    for i, (_, node) in enumerate(wn.nodes()):
        U[timestep_idx, i, 0] = float(node.name[-4:])
        U[timestep_idx, i, 1] = head.iloc[timestep_idx][i]

# %%
array_3d_shape = B.shape
new_shape = (array_3d_shape[0]* array_3d_shape[1] ,array_3d_shape[2])

# Reshaping the 3-dimensional array into a 2-dimensional array
B_2d = B.reshape(new_shape)

# Converting the 2-dimensional array into a DataFrame
node_df = pd.DataFrame(B_2d)

array_3d_shape = A.shape
new_shape = (array_3d_shape[0]* array_3d_shape[1] ,array_3d_shape[2])

# Reshaping the 3-dimensional array into a 2-dimensional array
A_2d = A.reshape(new_shape)

# Converting the 2-dimensional array into a DataFrame
edge_df = pd.DataFrame(A_2d)

array_3d_shape = U.shape
new_shape = (array_3d_shape[0]* array_3d_shape[1] ,array_3d_shape[2])

# Reshaping the 3-dimensional array into a 2-dimensional array
U_2d = U.reshape(new_shape)

# Converting the 2-dimensional array into a DataFrame
head_df = pd.DataFrame(U_2d)

# %%
head_df.rename(columns={0: 'Node_indicator',1: 'head'},inplace=True)
edge_df.rename(columns={0: 'source', 1: 'target', 2:'link_name',3: 'loss_co'},inplace=True)
node_df.rename(columns={0:'Time_indicator', 1: 'Node_indicator', 2:'Junction_in',3: 'demand', 4: 'Measurement_in',5:'measurement'},inplace=True)

# %%
node_df_copy = node_df.copy()

# Get the indices where Node_indicator is not in the monitor array
monitor_indices = node_df_copy.loc[~node_df_copy['Node_indicator'].isin(monitor)].index
nmonitor_indices = node_df_copy.loc[node_df_copy['Node_indicator'].isin(monitor)].index
# Set measurement to 0 for rows where Node_indicator is not in the monitor array
node_df_copy.loc[monitor_indices, 'measurement'] = 0
node_df_copy.loc[nmonitor_indices, 'Measurement_in'] = 1
# Display the modified DataFrame
print(node_df_copy)
# Out:
#         Time_indicator  Node_indicator  Junction_in    demand  Measurement_in  \
# 0                  0.0             1.0          0.0  0.000041             1.0
# 1                  0.0             3.0          0.0  0.000023             0.0
# 2                  0.0             4.0          0.0  0.000014             0.0
# 3                  0.0             5.0          0.0  0.000069             0.0
# 4                  0.0             6.0          0.0  0.000100             0.0
# ...                ...             ...          ...       ...             ...
# 107277         86400.0          2676.0          0.0  0.000082             0.0
# 107278         86400.0          2677.0          0.0  0.000014             0.0
# 107279         86400.0          2744.0          0.0  0.000085             0.0
# 107280         86400.0          2745.0          0.0  0.000014             0.0
# 107281         86400.0             1.0          1.0  0.000000             1.0
#
#         measurement
# 0         86.272728
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ...             ...
# 107277     0.000000
# 107278     0.000000
# 107279     0.000000
# 107280     0.000000
# 107281    87.054901
#
# [107282 rows x 6 columns]

# %%
edge_df.to_csv('edge_df.csv')
node_df_copy.to_csv('node_df.csv')
head_df.to_csv('head_df.csv')

# %%
test_edge_df = edge_df[num_links * (num_timesteps - 34):]
test_node_df = node_df_copy[ num_nodes * (num_timesteps - 34):]

train_edge_df = edge_df[: num_links * (num_timesteps - 60)]
train_node_df = node_df_copy[: num_nodes * (num_timesteps - 60)]

vali_edge_df = edge_df[ num_links * (num_timesteps - 60): num_links * (num_timesteps - 34)]
vali_node_df = node_df_copy[ num_nodes * (num_timesteps - 60): num_nodes * (num_timesteps - 34)]

# %%
def create_graph_tensor(node_df, edge_df):
    graph_tensor = tfgnn.GraphTensor.from_pieces(

        node_sets={
            "node": tfgnn.NodeSet.from_fields(
                sizes=[len(node_df)],
                features={
                    #'Node_indicator':np.array(node_df['Node_indicator'], dtype='int32').reshape(len(node_df),1),
                    'Junction_in':np.array(node_df['Junction_in'], dtype='int32').reshape(len(node_df),1),
                    'demand': np.array(node_df['demand'], dtype='float32').reshape(len(node_df),1),
                    'Measurement_in': np.array(node_df['Measurement_in'], dtype='int32').reshape(len(node_df),1),
                    'measurement': np.array(node_df['measurement'], dtype='float32').reshape(len(node_df),1),
                }
            )
        },
        edge_sets={
            "link": tfgnn.EdgeSet.from_fields(
                sizes=[len(edge_df)],
                features={
                    'loss_co': np.array(edge_df['loss_co'], dtype='float32').reshape(len(edge_df),1),
                },
                adjacency=tfgnn.Adjacency.from_indices(
                                          source=("node", np.array(edge_df['source'], dtype='int32')),
                                          target=("node", np.array(edge_df['target'], dtype='int32')),
                                      ))
        }
    )

    return graph_tensor

# %%
full_tensor = create_graph_tensor(node_df_copy, edge_df)
train_tensor = create_graph_tensor(train_node_df, train_edge_df)
test_tensor = create_graph_tensor(test_node_df, test_edge_df)
vali_tensor = create_graph_tensor(vali_node_df, vali_edge_df)

# %%
def node_batch_merge(graph):
    graph = graph.merge_batch_to_components()
    node_features = graph.node_sets['node'].get_features_dict()
    edge_features = graph.edge_sets['link'].get_features_dict()
    
    label = node_features.pop('measurement')
    print(label)
    new_graph = graph.replace_features(node_sets={'node': node_features}, edge_sets={'link': edge_features})
    
    return new_graph, label


     
def create_dataset(graph, function):
    dataset = tf.data.Dataset.from_tensors(graph)
    dataset = dataset.batch(32)
    return dataset.map(function)

# %%
full_node_dataset = create_dataset(full_tensor, node_batch_merge)
train_node_dataset = create_dataset(train_tensor, node_batch_merge)
test_node_dataset = create_dataset(test_tensor, node_batch_merge)
vali_node_dataset = create_dataset(vali_tensor, node_batch_merge)
# Out:
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)
# Tensor("Reshape_5:0", shape=(None, 1), dtype=float32)

# %%
graph_spec = train_node_dataset.element_spec[0]
input_graph = tf.keras.layers.Input(type_spec=graph_spec)

# %%
def set_initial_node_state(node_set, node_set_name):
    features = [
        #tf.keras.layers.Dense(32, activation="relu")(node_set['Node_indicator']),
        tf.keras.layers.Dense(32, activation=tf.nn.leaky_relu)(node_set['Junction_in']),
        tf.keras.layers.Dense(32, activation=tf.nn.leaky_relu)(node_set['demand']),
        tf.keras.layers.Dense(32, activation=tf.nn.leaky_relu)(node_set['Measurement_in'])
    ]
    return tf.keras.layers.Concatenate()(features)


def set_initial_edge_state(edge_set, edge_set_name):
    features = [
        tf.keras.layers.Dense(32, activation="leaky_relu")(edge_set['loss_co']),
    ]
    return tf.keras.layers.Concatenate()(features)

# %%
def dense_layer(units=128, l2_reg=0.01, dropout=0.5, activation='tf.nn.leaky_relu'):
    regularizer = tf.keras.regularizers.l2(l2_reg)
    return tf.keras.Sequential([
        tf.keras.layers.Dense(units, kernel_initializer='glorot_normal',kernel_regularizer=regularizer, bias_regularizer=regularizer),
        tf.keras.layers.Dropout(dropout)
    ])
graph = tfgnn.keras.layers.MapFeatures(node_sets_fn=set_initial_node_state,
                                       edge_sets_fn=set_initial_edge_state)(input_graph)
# Out:
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>

# %%
graph_updates = 6
l2_reg = 0.01
regularizer = tf.keras.regularizers.l2(l2_reg)
for i in range(graph_updates):
    graph = tfgnn.keras.layers.GraphUpdate(
        node_sets={
            'node':
            tfgnn.keras.layers.NodeSetUpdate(
                {
                    'link':
                    tfgnn.keras.layers.SimpleConv(message_fn=dense_layer(128),
                                                  reduce_type="mean",
                                                  sender_edge_feature=tfgnn.HIDDEN_STATE,
                                                  receiver_tag=tfgnn.TARGET)
                }, tfgnn.keras.layers.NextStateFromConcat(dense_layer(64)))
        })(graph)
    dense1 = tf.keras.layers.Dense(128,activation=tf.nn.leaky_relu)(graph.node_sets["node"][tfgnn.HIDDEN_STATE])
    dense2 = tf.keras.layers.Dense(64)(dense1)
    dense3 = tf.keras.layers.Dense(64)(dense2)
    dense4 = tf.keras.layers.Dense(1)(dense3)

# %%
node_model = tf.keras.Model(input_graph, dense4)
node_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                   loss='mean_squared_error',
                   metrics=['mean_squared_error'])
node_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [()]                      0
#
#  map_features (MapFeatures)  ()                        256
#
#  graph_update (GraphUpdate)  ()                        43200
#
#  graph_update_1 (GraphUpdate  ()                       32960
#  )
#
#  graph_update_2 (GraphUpdate  ()                       32960
#  )
#
#  graph_update_3 (GraphUpdate  ()                       32960
#  )
#
#  graph_update_4 (GraphUpdate  ()                       32960
#  )
#
#  graph_update_5 (GraphUpdate  ()                       32960
#  )
#
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
#  input.node_sets_5 (Instance  {'node': ()}             0
#  Property)
#
#  input._get_features_ref_9 (  {'hidden_state': (None,   0
#  InstanceProperty)           64)}
#
#  dense_32 (Dense)            (None, 128)               8320
#
#  dense_33 (Dense)            (None, 64)                8256
#
#  dense_34 (Dense)            (None, 64)                4160
#
#  dense_35 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 229,057
# Trainable params: 229,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                      mode='min',
                                      verbose=10,
                                      patience=10,
                                      restore_best_weights=True)

node_model.fit(full_node_dataset.repeat(),
               validation_data=full_node_dataset,
               steps_per_epoch=10,
               epochs=200,
               callbacks=[es])
# Out:
# Epoch 1/200
# 10/10 [==============================] - 19s 2s/step - loss: 2.2569 - mean_squared_error: 1.1824 - val_loss: 2.2021 - val_mean_squared_error: 1.1302
# Epoch 2/200
# 10/10 [==============================] - 20s 2s/step - loss: 2.2449 - mean_squared_error: 1.1750 - val_loss: 2.1999 - val_mean_squared_error: 1.1325
# Epoch 3/200
# 10/10 [==============================] - 20s 2s/step - loss: 2.2404 - mean_squared_error: 1.1750 - val_loss: 2.2032 - val_mean_squared_error: 1.1401
# Epoch 4/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2347 - mean_squared_error: 1.1734 - val_loss: 2.1891 - val_mean_squared_error: 1.1300
# Epoch 5/200
# 10/10 [==============================] - 20s 2s/step - loss: 2.2285 - mean_squared_error: 1.1712 - val_loss: 2.1934 - val_mean_squared_error: 1.1385
# Epoch 6/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2262 - mean_squared_error: 1.1733 - val_loss: 2.1982 - val_mean_squared_error: 1.1476
# Epoch 7/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2316 - mean_squared_error: 1.1830 - val_loss: 2.2088 - val_mean_squared_error: 1.1627
# Epoch 8/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2260 - mean_squared_error: 1.1818 - val_loss: 2.1722 - val_mean_squared_error: 1.1304
# Epoch 9/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2109 - mean_squared_error: 1.1711 - val_loss: 2.1696 - val_mean_squared_error: 1.1323
# Epoch 10/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2030 - mean_squared_error: 1.1676 - val_loss: 2.1615 - val_mean_squared_error: 1.1285
# Epoch 11/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2072 - mean_squared_error: 1.1760 - val_loss: 2.2074 - val_mean_squared_error: 1.1784
# Epoch 12/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.3139 - mean_squared_error: 1.2870 - val_loss: 2.2151 - val_mean_squared_error: 1.1913
# Epoch 13/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.2321 - mean_squared_error: 1.2106 - val_loss: 2.1579 - val_mean_squared_error: 1.1389
# Epoch 14/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.1991 - mean_squared_error: 1.1821 - val_loss: 2.1491 - val_mean_squared_error: 1.1343
# Epoch 15/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.1858 - mean_squared_error: 1.1728 - val_loss: 2.1415 - val_mean_squared_error: 1.1306
# Epoch 16/200
# 10/10 [==============================] - 21s 2s/step - loss: 2.1866 - mean_squared_error: 1.1773 - val_loss: 2.1523 - val_mean_squared_error: 1.1451
# Epoch 17/200
# 10/10 [==============================] - 29s 3s/step - loss: 2.1830 - mean_squared_error: 1.1776 - val_loss: 2.1464 - val_mean_squared_error: 1.1432
# Epoch 18/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1724 - mean_squared_error: 1.1712 - val_loss: 2.1273 - val_mean_squared_error: 1.1285
# Epoch 19/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1726 - mean_squared_error: 1.1758 - val_loss: 2.1261 - val_mean_squared_error: 1.1316
# Epoch 20/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1567 - mean_squared_error: 1.1642 - val_loss: 2.1253 - val_mean_squared_error: 1.1352
# Epoch 21/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1548 - mean_squared_error: 1.1668 - val_loss: 2.1170 - val_mean_squared_error: 1.1314
# Epoch 22/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1495 - mean_squared_error: 1.1658 - val_loss: 2.1126 - val_mean_squared_error: 1.1311
# Epoch 23/200
# 10/10 [==============================] - 22s 2s/step - loss: 2.1520 - mean_squared_error: 1.1724 - val_loss: 2.1350 - val_mean_squared_error: 1.1576
# Epoch 24/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1422 - mean_squared_error: 1.1667 - val_loss: 2.1029 - val_mean_squared_error: 1.1298
# Epoch 25/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1378 - mean_squared_error: 1.1666 - val_loss: 2.1001 - val_mean_squared_error: 1.1312
# Epoch 26/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.1269 - mean_squared_error: 1.1600 - val_loss: 2.0995 - val_mean_squared_error: 1.1349
# Epoch 27/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1300 - mean_squared_error: 1.1673 - val_loss: 2.0999 - val_mean_squared_error: 1.1394
# Epoch 28/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1643 - mean_squared_error: 1.2058 - val_loss: 2.1033 - val_mean_squared_error: 1.1473
# Epoch 29/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.1234 - mean_squared_error: 1.1695 - val_loss: 2.0912 - val_mean_squared_error: 1.1398
# Epoch 30/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1118 - mean_squared_error: 1.1623 - val_loss: 2.0791 - val_mean_squared_error: 1.1320
# Epoch 31/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1130 - mean_squared_error: 1.1676 - val_loss: 2.0748 - val_mean_squared_error: 1.1316
# Epoch 32/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1002 - mean_squared_error: 1.1588 - val_loss: 2.0711 - val_mean_squared_error: 1.1319
# Epoch 33/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.1027 - mean_squared_error: 1.1653 - val_loss: 2.0763 - val_mean_squared_error: 1.1412
# Epoch 34/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1585 - mean_squared_error: 1.2254 - val_loss: 2.0729 - val_mean_squared_error: 1.1424
# Epoch 35/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.1064 - mean_squared_error: 1.1780 - val_loss: 2.0728 - val_mean_squared_error: 1.1468
# Epoch 36/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0928 - mean_squared_error: 1.1687 - val_loss: 2.0547 - val_mean_squared_error: 1.1328
# Epoch 37/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0843 - mean_squared_error: 1.1643 - val_loss: 2.0505 - val_mean_squared_error: 1.1328
# Epoch 38/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0764 - mean_squared_error: 1.1605 - val_loss: 2.0510 - val_mean_squared_error: 1.1374
# Epoch 39/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0696 - mean_squared_error: 1.1578 - val_loss: 2.0399 - val_mean_squared_error: 1.1304
# Epoch 40/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0728 - mean_squared_error: 1.1651 - val_loss: 2.0370 - val_mean_squared_error: 1.1314
# Epoch 41/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0613 - mean_squared_error: 1.1575 - val_loss: 2.0452 - val_mean_squared_error: 1.1437
# Epoch 42/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0569 - mean_squared_error: 1.1573 - val_loss: 2.0273 - val_mean_squared_error: 1.1301
# Epoch 43/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0527 - mean_squared_error: 1.1574 - val_loss: 2.0230 - val_mean_squared_error: 1.1300
# Epoch 44/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0533 - mean_squared_error: 1.1620 - val_loss: 2.0240 - val_mean_squared_error: 1.1349
# Epoch 45/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0475 - mean_squared_error: 1.1602 - val_loss: 2.0265 - val_mean_squared_error: 1.1414
# Epoch 46/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0501 - mean_squared_error: 1.1668 - val_loss: 2.0139 - val_mean_squared_error: 1.1327
# Epoch 47/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0495 - mean_squared_error: 1.1703 - val_loss: 2.0081 - val_mean_squared_error: 1.1312
# Epoch 48/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0384 - mean_squared_error: 1.1634 - val_loss: 2.0177 - val_mean_squared_error: 1.1451
# Epoch 49/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0328 - mean_squared_error: 1.1620 - val_loss: 1.9997 - val_mean_squared_error: 1.1312
# Epoch 50/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0269 - mean_squared_error: 1.1603 - val_loss: 1.9959 - val_mean_squared_error: 1.1316
# Epoch 51/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0252 - mean_squared_error: 1.1626 - val_loss: 2.0121 - val_mean_squared_error: 1.1517
# Epoch 52/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0636 - mean_squared_error: 1.2050 - val_loss: 2.0277 - val_mean_squared_error: 1.1716
# Epoch 53/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0215 - mean_squared_error: 1.1675 - val_loss: 1.9887 - val_mean_squared_error: 1.1371
# Epoch 54/200
# 10/10 [==============================] - 25s 2s/step - loss: 2.0129 - mean_squared_error: 1.1632 - val_loss: 1.9904 - val_mean_squared_error: 1.1429
# Epoch 55/200
# 10/10 [==============================] - 24s 2s/step - loss: 2.0086 - mean_squared_error: 1.1629 - val_loss: 1.9769 - val_mean_squared_error: 1.1333
# Epoch 56/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9941 - mean_squared_error: 1.1523 - val_loss: 1.9732 - val_mean_squared_error: 1.1336
# Epoch 57/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.9940 - mean_squared_error: 1.1562 - val_loss: 1.9669 - val_mean_squared_error: 1.1312
# Epoch 58/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9894 - mean_squared_error: 1.1555 - val_loss: 1.9647 - val_mean_squared_error: 1.1330
# Epoch 59/200
# 10/10 [==============================] - 23s 2s/step - loss: 2.0039 - mean_squared_error: 1.1740 - val_loss: 1.9982 - val_mean_squared_error: 1.1707
# Epoch 60/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9998 - mean_squared_error: 1.1742 - val_loss: 1.9562 - val_mean_squared_error: 1.1331
# Epoch 61/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9769 - mean_squared_error: 1.1556 - val_loss: 1.9512 - val_mean_squared_error: 1.1321
# Epoch 62/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9734 - mean_squared_error: 1.1560 - val_loss: 1.9491 - val_mean_squared_error: 1.1338
# Epoch 63/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9715 - mean_squared_error: 1.1579 - val_loss: 1.9446 - val_mean_squared_error: 1.1331
# Epoch 64/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9653 - mean_squared_error: 1.1556 - val_loss: 1.9399 - val_mean_squared_error: 1.1323
# Epoch 65/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9613 - mean_squared_error: 1.1554 - val_loss: 1.9365 - val_mean_squared_error: 1.1327
# Epoch 66/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9613 - mean_squared_error: 1.1593 - val_loss: 1.9384 - val_mean_squared_error: 1.1386
# Epoch 67/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9576 - mean_squared_error: 1.1597 - val_loss: 1.9285 - val_mean_squared_error: 1.1329
# Epoch 68/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9448 - mean_squared_error: 1.1511 - val_loss: 1.9232 - val_mean_squared_error: 1.1318
# Epoch 69/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9463 - mean_squared_error: 1.1566 - val_loss: 1.9194 - val_mean_squared_error: 1.1317
# Epoch 70/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9369 - mean_squared_error: 1.1508 - val_loss: 1.9158 - val_mean_squared_error: 1.1317
# Epoch 71/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9350 - mean_squared_error: 1.1526 - val_loss: 1.9189 - val_mean_squared_error: 1.1386
# Epoch 72/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9453 - mean_squared_error: 1.1667 - val_loss: 1.9730 - val_mean_squared_error: 1.1966
# Epoch 73/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9837 - mean_squared_error: 1.2094 - val_loss: 1.9162 - val_mean_squared_error: 1.1445
# Epoch 74/200
# 10/10 [==============================] - 25s 2s/step - loss: 1.9408 - mean_squared_error: 1.1711 - val_loss: 1.9106 - val_mean_squared_error: 1.1431
# Epoch 75/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9261 - mean_squared_error: 1.1602 - val_loss: 1.9009 - val_mean_squared_error: 1.1369
# Epoch 76/200
# 10/10 [==============================] - 25s 2s/step - loss: 1.9176 - mean_squared_error: 1.1551 - val_loss: 1.8926 - val_mean_squared_error: 1.1321
# Epoch 77/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9172 - mean_squared_error: 1.1582 - val_loss: 1.8950 - val_mean_squared_error: 1.1380
# Epoch 78/200
# 10/10 [==============================] - 25s 2s/step - loss: 1.9107 - mean_squared_error: 1.1554 - val_loss: 1.8867 - val_mean_squared_error: 1.1333
# Epoch 79/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9050 - mean_squared_error: 1.1533 - val_loss: 1.8956 - val_mean_squared_error: 1.1461
# Epoch 80/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9525 - mean_squared_error: 1.2049 - val_loss: 1.8791 - val_mean_squared_error: 1.1341
# Epoch 81/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.9095 - mean_squared_error: 1.1664 - val_loss: 1.8843 - val_mean_squared_error: 1.1436
# Epoch 82/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8988 - mean_squared_error: 1.1599 - val_loss: 1.8687 - val_mean_squared_error: 1.1320
# Epoch 83/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8932 - mean_squared_error: 1.1581 - val_loss: 1.8693 - val_mean_squared_error: 1.1361
# Epoch 84/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8862 - mean_squared_error: 1.1546 - val_loss: 1.8630 - val_mean_squared_error: 1.1334
# Epoch 85/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8851 - mean_squared_error: 1.1571 - val_loss: 1.8591 - val_mean_squared_error: 1.1330
# Epoch 86/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8774 - mean_squared_error: 1.1529 - val_loss: 1.8571 - val_mean_squared_error: 1.1346
# Epoch 87/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8751 - mean_squared_error: 1.1542 - val_loss: 1.8513 - val_mean_squared_error: 1.1323
# Epoch 88/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8666 - mean_squared_error: 1.1492 - val_loss: 1.8528 - val_mean_squared_error: 1.1375
# Epoch 89/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8699 - mean_squared_error: 1.1563 - val_loss: 1.8440 - val_mean_squared_error: 1.1324
# Epoch 90/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8591 - mean_squared_error: 1.1492 - val_loss: 1.8401 - val_mean_squared_error: 1.1322
# Epoch 91/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8587 - mean_squared_error: 1.1523 - val_loss: 1.8389 - val_mean_squared_error: 1.1344
# Epoch 92/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8692 - mean_squared_error: 1.1663 - val_loss: 1.8626 - val_mean_squared_error: 1.1618
# Epoch 93/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8582 - mean_squared_error: 1.1592 - val_loss: 1.8297 - val_mean_squared_error: 1.1329
# Epoch 94/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8494 - mean_squared_error: 1.1543 - val_loss: 1.8326 - val_mean_squared_error: 1.1396
# Epoch 95/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8425 - mean_squared_error: 1.1511 - val_loss: 1.8224 - val_mean_squared_error: 1.1330
# Epoch 96/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8362 - mean_squared_error: 1.1485 - val_loss: 1.8184 - val_mean_squared_error: 1.1326
# Epoch 97/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8381 - mean_squared_error: 1.1538 - val_loss: 1.8158 - val_mean_squared_error: 1.1333
# Epoch 98/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8322 - mean_squared_error: 1.1511 - val_loss: 1.8272 - val_mean_squared_error: 1.1479
# Epoch 99/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8888 - mean_squared_error: 1.2112 - val_loss: 1.8095 - val_mean_squared_error: 1.1345
# Epoch 100/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8411 - mean_squared_error: 1.1680 - val_loss: 1.8134 - val_mean_squared_error: 1.1426
# Epoch 101/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8211 - mean_squared_error: 1.1519 - val_loss: 1.8000 - val_mean_squared_error: 1.1327
# Epoch 102/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8163 - mean_squared_error: 1.1506 - val_loss: 1.7965 - val_mean_squared_error: 1.1327
# Epoch 103/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8155 - mean_squared_error: 1.1532 - val_loss: 1.7930 - val_mean_squared_error: 1.1326
# Epoch 104/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.8088 - mean_squared_error: 1.1500 - val_loss: 1.7920 - val_mean_squared_error: 1.1350
# Epoch 105/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8073 - mean_squared_error: 1.1518 - val_loss: 1.7866 - val_mean_squared_error: 1.1328
# Epoch 106/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8074 - mean_squared_error: 1.1551 - val_loss: 1.7835 - val_mean_squared_error: 1.1330
# Epoch 107/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.8013 - mean_squared_error: 1.1522 - val_loss: 1.7799 - val_mean_squared_error: 1.1326
# Epoch 108/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7919 - mean_squared_error: 1.1462 - val_loss: 1.7779 - val_mean_squared_error: 1.1341
# Epoch 109/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7906 - mean_squared_error: 1.1485 - val_loss: 1.7726 - val_mean_squared_error: 1.1326
# Epoch 110/200
# 10/10 [==============================] - 25s 2s/step - loss: 1.7897 - mean_squared_error: 1.1513 - val_loss: 1.7790 - val_mean_squared_error: 1.1427
# Epoch 111/200
# 10/10 [==============================] - 25s 2s/step - loss: 1.7855 - mean_squared_error: 1.1508 - val_loss: 1.7699 - val_mean_squared_error: 1.1373
# Epoch 112/200
# 10/10 [==============================] - 26s 3s/step - loss: 1.7821 - mean_squared_error: 1.1510 - val_loss: 1.7653 - val_mean_squared_error: 1.1361
# Epoch 113/200
# 10/10 [==============================] - 25s 2s/step - loss: 1.7756 - mean_squared_error: 1.1479 - val_loss: 1.7583 - val_mean_squared_error: 1.1325
# Epoch 114/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7704 - mean_squared_error: 1.1460 - val_loss: 1.7563 - val_mean_squared_error: 1.1337
# Epoch 115/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7745 - mean_squared_error: 1.1534 - val_loss: 1.7614 - val_mean_squared_error: 1.1423
# Epoch 116/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7700 - mean_squared_error: 1.1524 - val_loss: 1.7528 - val_mean_squared_error: 1.1372
# Epoch 117/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7646 - mean_squared_error: 1.1505 - val_loss: 1.7448 - val_mean_squared_error: 1.1325
# Epoch 118/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7591 - mean_squared_error: 1.1482 - val_loss: 1.7440 - val_mean_squared_error: 1.1350
# Epoch 119/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7557 - mean_squared_error: 1.1481 - val_loss: 1.7409 - val_mean_squared_error: 1.1352
# Epoch 120/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7663 - mean_squared_error: 1.1621 - val_loss: 1.7503 - val_mean_squared_error: 1.1481
# Epoch 121/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7529 - mean_squared_error: 1.1524 - val_loss: 1.7332 - val_mean_squared_error: 1.1346
# Epoch 122/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7461 - mean_squared_error: 1.1490 - val_loss: 1.7277 - val_mean_squared_error: 1.1324
# Epoch 123/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7448 - mean_squared_error: 1.1509 - val_loss: 1.7262 - val_mean_squared_error: 1.1339
# Epoch 124/200
# 10/10 [==============================] - 25s 3s/step - loss: 1.7374 - mean_squared_error: 1.1464 - val_loss: 1.7252 - val_mean_squared_error: 1.1359
# Epoch 125/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7548 - mean_squared_error: 1.1669 - val_loss: 1.7819 - val_mean_squared_error: 1.1959
# Epoch 126/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7677 - mean_squared_error: 1.1836 - val_loss: 1.7158 - val_mean_squared_error: 1.1341
# Epoch 127/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7328 - mean_squared_error: 1.1528 - val_loss: 1.7138 - val_mean_squared_error: 1.1357
# Epoch 128/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7266 - mean_squared_error: 1.1499 - val_loss: 1.7118 - val_mean_squared_error: 1.1367
# Epoch 129/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7215 - mean_squared_error: 1.1477 - val_loss: 1.7055 - val_mean_squared_error: 1.1332
# Epoch 130/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7172 - mean_squared_error: 1.1463 - val_loss: 1.7052 - val_mean_squared_error: 1.1359
# Epoch 131/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7277 - mean_squared_error: 1.1598 - val_loss: 1.6984 - val_mean_squared_error: 1.1324
# Epoch 132/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7143 - mean_squared_error: 1.1497 - val_loss: 1.7017 - val_mean_squared_error: 1.1389
# Epoch 133/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7119 - mean_squared_error: 1.1506 - val_loss: 1.6957 - val_mean_squared_error: 1.1362
# Epoch 134/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7069 - mean_squared_error: 1.1487 - val_loss: 1.6905 - val_mean_squared_error: 1.1341
# Epoch 135/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7016 - mean_squared_error: 1.1465 - val_loss: 1.6867 - val_mean_squared_error: 1.1333
# Epoch 136/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.7003 - mean_squared_error: 1.1482 - val_loss: 1.6900 - val_mean_squared_error: 1.1394
# Epoch 137/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.7210 - mean_squared_error: 1.1717 - val_loss: 1.6938 - val_mean_squared_error: 1.1462
# Epoch 138/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6996 - mean_squared_error: 1.1536 - val_loss: 1.6778 - val_mean_squared_error: 1.1337
# Epoch 139/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6914 - mean_squared_error: 1.1488 - val_loss: 1.6822 - val_mean_squared_error: 1.1413
# Epoch 140/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6902 - mean_squared_error: 1.1506 - val_loss: 1.6739 - val_mean_squared_error: 1.1360
# Epoch 141/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6900 - mean_squared_error: 1.1535 - val_loss: 1.6751 - val_mean_squared_error: 1.1402
# Epoch 142/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6813 - mean_squared_error: 1.1477 - val_loss: 1.6667 - val_mean_squared_error: 1.1348
# Epoch 143/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6766 - mean_squared_error: 1.1460 - val_loss: 1.6629 - val_mean_squared_error: 1.1338
# Epoch 144/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6761 - mean_squared_error: 1.1483 - val_loss: 1.6635 - val_mean_squared_error: 1.1373
# Epoch 145/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6948 - mean_squared_error: 1.1699 - val_loss: 1.7089 - val_mean_squared_error: 1.1859
# Epoch 146/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6880 - mean_squared_error: 1.1668 - val_loss: 1.6522 - val_mean_squared_error: 1.1330
# Epoch 147/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6682 - mean_squared_error: 1.1504 - val_loss: 1.6497 - val_mean_squared_error: 1.1334
# Epoch 148/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6605 - mean_squared_error: 1.1454 - val_loss: 1.6513 - val_mean_squared_error: 1.1377
# Epoch 149/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6603 - mean_squared_error: 1.1481 - val_loss: 1.6481 - val_mean_squared_error: 1.1376
# Epoch 150/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6653 - mean_squared_error: 1.1560 - val_loss: 1.6432 - val_mean_squared_error: 1.1356
# Epoch 151/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6541 - mean_squared_error: 1.1478 - val_loss: 1.6403 - val_mean_squared_error: 1.1356
# Epoch 152/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6499 - mean_squared_error: 1.1466 - val_loss: 1.6416 - val_mean_squared_error: 1.1400
# Epoch 153/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6471 - mean_squared_error: 1.1468 - val_loss: 1.6345 - val_mean_squared_error: 1.1358
# Epoch 154/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6466 - mean_squared_error: 1.1492 - val_loss: 1.6366 - val_mean_squared_error: 1.1407
# Epoch 155/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6458 - mean_squared_error: 1.1512 - val_loss: 1.6270 - val_mean_squared_error: 1.1339
# Epoch 156/200
# 10/10 [==============================] - 24s 2s/step - loss: 1.6362 - mean_squared_error: 1.1443 - val_loss: 1.6298 - val_mean_squared_error: 1.1396
# Epoch 157/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6436 - mean_squared_error: 1.1548 - val_loss: 1.6269 - val_mean_squared_error: 1.1397
# Epoch 158/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6342 - mean_squared_error: 1.1484 - val_loss: 1.6235 - val_mean_squared_error: 1.1391
# Epoch 159/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6338 - mean_squared_error: 1.1508 - val_loss: 1.6145 - val_mean_squared_error: 1.1331
# Epoch 160/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6276 - mean_squared_error: 1.1475 - val_loss: 1.6122 - val_mean_squared_error: 1.1337
# Epoch 161/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6288 - mean_squared_error: 1.1517 - val_loss: 1.6216 - val_mean_squared_error: 1.1460
# Epoch 162/200
# 10/10 [==============================] - 22s 2s/step - loss: 1.6266 - mean_squared_error: 1.1523 - val_loss: 1.6074 - val_mean_squared_error: 1.1347
# Epoch 163/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6186 - mean_squared_error: 1.1471 - val_loss: 1.6044 - val_mean_squared_error: 1.1344
# Epoch 164/200
# 10/10 [==============================] - 22s 2s/step - loss: 1.6151 - mean_squared_error: 1.1462 - val_loss: 1.6062 - val_mean_squared_error: 1.1388
# Epoch 165/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6744 - mean_squared_error: 1.2081 - val_loss: 1.6794 - val_mean_squared_error: 1.2151
# Epoch 166/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6400 - mean_squared_error: 1.1777 - val_loss: 1.6083 - val_mean_squared_error: 1.1482
# Epoch 167/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6210 - mean_squared_error: 1.1621 - val_loss: 1.5982 - val_mean_squared_error: 1.1407
# Epoch 168/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6060 - mean_squared_error: 1.1493 - val_loss: 1.5961 - val_mean_squared_error: 1.1404
# Epoch 169/200
# 10/10 [==============================] - 23s 2s/step - loss: 1.6097 - mean_squared_error: 1.1550 - val_loss: 1.5982 - val_mean_squared_error: 1.1448
# Epoch 170/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 7
#       1 es = tf.keras.callbacks.EarlyStopping(monitor='loss',
#       2                                       mode='min',
#       3                                       verbose=10,
#       4                                       patience=10,
#       5                                       restore_best_weights=True)
# ----> 7 node_model.fit(full_node_dataset.repeat(),
#       8                validation_data=full_node_dataset,
#       9                steps_per_epoch=10,
#      10                epochs=200,
#      11                callbacks=[es])
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
predictions = pd.DataFrame(node_model.predict(full_node_dataset))
print(predictions)
# Out:
# 1/1 [==============================] - 1s 769ms/step
#                 0
# 0       82.023430
# 1       -0.103521
# 2       -0.103544
# 3       -0.103525
# 4       -0.103525
# ...           ...
# 107277  -0.103551
# 107278  -0.103544
# 107279  -0.103549
# 107280  -0.103544
# 107281  82.044395
#
# [107282 rows x 1 columns]

# %%
residuals =  head_df['head']- (predictions[0])

# %%
predictions.to_csv('semi-L.csv')

# %%
ana
# Out:
#           node  predictions  residuals
# 0          1.0    82.023430   4.249298
# 1          3.0    -0.103521  86.122709
# 2          4.0    -0.103544  86.134230
# 3          5.0    -0.103525  86.154406
# 4          6.0    -0.103525  86.132380
# ...        ...          ...        ...
# 107277  2676.0    -0.103551  84.981893
# 107278  2677.0    -0.103544  84.981077
# 107279  2744.0    -0.103549  84.996188
# 107280  2745.0    -0.103544  86.125227
# 107281     1.0    82.044395   5.010506
#
# [107282 rows x 3 columns]

# %%
ana = pd.DataFrame({
    'node':node_df['Node_indicator'],
    'predictions': predictions[0],
    'residuals': residuals
})
Pre_array =  np.array(predictions).reshape((-1, num_nodes,1))
Pre_array = np.mean(Pre_array, axis=2)
Pre_ana = pd.DataFrame(Pre_array, columns=['Node ' + str(i+1) for i in range(num_nodes)])
Pre_ana['Node 1']
# Out:
# 0     82.023430
# 1     82.023438
# 2     82.023453
# 3     82.023445
# 4     82.023445
#         ...
# 92    82.023430
# 93    82.023415
# 94    82.023422
# 95    82.023422
# 96    82.023430
# Name: Node 1, Length: 97, dtype: float32

# %%
head_at_node514 = head.loc[:,'node_0001']
ax = head_at_node5.plot()
ax.set_xlabel("Time (s)")
ax.set_ylabel("head (m)")
Pre_ana = Pre_ana.set_index(head.index)

Pre_ana['Node 1'].plot(ax=ax)
plt.title('Hydraulic Head at Node 1 (Semi-Supervised, Large Network)')
plt.legend(['Real Value', 'Predicted Value'])
plt.savefig('Hydraulic Head at Node 1 (Semi-Supervised, Large Network).png')
plt.show()

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
sns.histplot(residuals, kde=True, bins=20)  # kde=True adds a Kernel Density Estimation curve
plt.xlabel('Residuals (m)')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.title('Distribution of Residuals (Semi-Supervised, Large Network)')
plt.savefig('Distribution of Residuals (Semi-Supervised, Large Network).png')
plt.show()

# %%
RESI = ana[ana['node'].isin(monitor)]['residuals']
Other_RESI = ana[~ana['node'].isin(monitor)]['residuals']
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
sns.histplot(RESI, kde=True, bins=20)  # kde=True adds a Kernel Density Estimation curve
plt.xlabel('Residuals (m)')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals at Monitors (Semi-Supervised, Large Network)')

plt.savefig('Distribution of Residuals at Monitors (Semi-Supervised, Large Network).png')
plt.show()

# %%
residuals.max()
# Out:
# 88.13980969786644

# %%
residuals.min()
# Out:
# -9.311424255371094

# %%
RESI.max()
# Out:
# 5.99200439453125

# %%
RESI.min()
# Out:
# -9.311424255371094
